# %% [markdown]
# ## Likes Report
# By Alex Hillwig using his own Instagram Data

# %% [markdown]
# This report was created to analyze how often I like instagram Accounts.
#
# I ask this question because I wanted to draw conclusions from my likes in order to see what trends I followed as I liked posts.

# %% [markdown]
# I accessed this data through Instagram, which was downloaded as a Json file
#
# As a starting point, I needed to import json and panda libraries for Python 3

# %%
import json
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Here I loaded in the data from the file on my pc.

# %%
with open(r'C:\Users\jchil\Documents\Classes_21-22\DataInEmat\InstagramData\HillwigData\likes\liked_posts.json') as l:
    likes = json.load(l)
likes
# Out:
# {'likes_media_likes': [{'title': 'evan_moeller',
#    'media_list_data': [],
#    'string_list_data': [{'href': '',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1609453255}]},
#   {'title': 'nickhurst31_',
#    'media_list_data': [],
#    'string_list_data': [{'href': '',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1606602814}]},
#   {'title': 'ricester11',
#    'media_list_data': [],
#    'string_list_data': [{'href': '',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1605896455}]},
#   {'title': 'jordanjarc',
#    'media_list_data': [],
#    'string_list_data': [{'href': '',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1604066358}]},
#   {'title': 'ricester11',
#    'media_list_data': [],
#    'string_list_data': [{'href': '',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1603722319}]},
#   {'title': 'avajkatz',
#    'media_list_data': [],
#    'string_list_data': [{'href': '',
#      'value': 'ð\x9f\x91\x8d',
# ...

# %% [markdown]
# The "liked_posts.json" file contains data from users that I have liked with my Instagram account.
#
# The JSON files was converted to a DataFrame and summarized by counting each like per account.

# %%
likes.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
type(likes['likes_media_likes'])
# Out:
# list

# %%
likes['likes_media_likes'][0]
# Out:
# {'title': 'evan_moeller',
#  'media_list_data': [],
#  'string_list_data': [{'href': '',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1609453255}]}

# %%
type(likes['likes_media_likes'][0])
# Out:
# dict

# %%
likes['likes_media_likes'][0]['title']
# Out:
# 'evan_moeller'

# %%
likes['likes_media_likes'][0]['string_list_data'][0]['timestamp']
# Out:
# 1609453255

# %% [markdown]
# Here I listed every account I had liked's name and iterated it as many timesI had liked for every account, which is why there are many names repeated.

# %%
accounts = [x['title'] for x in likes['likes_media_likes']]
accounts
# Out:
# ['evan_moeller',
#  'nickhurst31_',
#  'ricester11',
#  'jordanjarc',
#  'ricester11',
#  'avajkatz',
#  'mangosmoothie64',
#  '4jtreu',
#  'sydney.skwera',
#  'ricester11',
#  'emmasalancy',
#  'allysmithh_',
#  'zomelon',
#  'rylanmahany',
#  'nickhurst31_',
#  'keelylisco',
#  'caitlinbrenner_',
#  'ricester11',
#  'rachelcovell',
#  'shaylyn_mcnally',
#  'nick.hartman.12',
#  'paul.amado',
#  'mangosmoothie64',
#  'nickhurst31_',
#  'taking.you.to.memetown',
#  'grace_lopiccolo',
#  'maddysloaf',
#  'nickhurst31_',
#  '_emmahouseholder',
#  'derpyreagan',
#  'jlc.2',
#  '_emmahouseholder',
#  '_emmahouseholder',
#  'reilleta',
#  '_reemak_',
#  'emmasalancy',
#  'nickhurst31_',
#  'francescacmaria',
#  'katevscanlan',
#  'rylanmahany',
#  'abby_summers__',
#  'haleycramer_',
#  'dean._.smith',
#  'annamadden_',
#  'madilynnk',
#  'abby_summers__',
#  '4jtreu',
#  'gianna.talento',
#  'mckennamccright',
#  'amber.liz28',
#  'mank.jpg',
#  'jlc.2',
#  '_elizabethmsalgado',
# ...

# %%
timestamp = [x['string_list_data'][0]['timestamp'] for x in likes['likes_media_likes']]
timestamp
# Out:
# [1609453255,
#  1606602814,
#  1605896455,
#  1604066358,
#  1603722319,
#  1603124996,
#  1602983540,
#  1602983537,
#  1600670950,
#  1600209782,
#  1600005934,
#  1599175217,
#  1599105906,
#  1597081889,
#  1597081888,
#  1596491109,
#  1595955941,
#  1595523699,
#  1595455612,
#  1595455606,
#  1595170774,
#  1595026712,
#  1594871660,
#  1594701413,
#  1594701271,
#  1594341415,
#  1594336413,
#  1594336372,
#  1594304234,
#  1594157558,
#  1594157557,
#  1593552742,
#  1593552740,
#  1593493454,
#  1593489429,
#  1593489422,
#  1593489411,
#  1592976624,
#  1592861084,
#  1592161528,
#  1589433284,
#  1588432657,
#  1588396574,
#  1588373427,
#  1587565605,
#  1587311003,
#  1585779869,
#  1583530207,
#  1582677069,
#  1582677067,
#  1582677063,
#  1582677060,
#  1582677059,
#  1582504009,
#  1582471949,
#  1582471948,
#  1582471945,
#  1582471942,
#  1582471941,
#  1582471939,
#  1582471937,
#  1582471924,
#  1582471922,
#  1582471909,
#  1582471889,
#  1582471887,
# ...

# %%
print(len(accounts), len(timestamp))
# Out:
# 223 223

# %% [markdown]
# # Analysis

# %%
likes_df = pd.DataFrame({'accounts': accounts, 'timestamp': timestamp})
likes_df
# Out:
#                  accounts   timestamp
# 0            evan_moeller  1609453255
# 1            nickhurst31_  1606602814
# 2              ricester11  1605896455
# 3              jordanjarc  1604066358
# 4              ricester11  1603722319
# ..                    ...         ...
# 218  p33p_b33p_m3m3_cr33p  1483458231
# 219  p33p_b33p_m3m3_cr33p  1483458223
# 220  p33p_b33p_m3m3_cr33p  1483458219
# 221  p33p_b33p_m3m3_cr33p  1483242079
# 222            moparfan51  1473084829
#
# [223 rows x 2 columns]

# %%
count_likes = likes_df.groupby('accounts').count()
count_likes
# Out:
#                         timestamp
# accounts
# 1023geis                        1
# 4jtreu                          3
# _elizabethmsalgado              1
# _emmahouseholder                5
# _reemak_                        2
# ...                           ...
# sydney.skwera                   1
# sydneymcgahey                   2
# sydni_mcconnell.08              3
# taking.you.to.memetown          1
# zomelon                         1
#
# [82 rows x 1 columns]

# %%
count_likes.sort_values('timestamp' ,ascending=False)
# Out:
#                       timestamp
# accounts
# bitchy.brown_                25
# p33p_b33p_m3m3_cr33p         17
# reilleta                     15
# abby_summers__               11
# mangosmoothie64               9
# ...                         ...
# johnsmolic_                   1
# jordanjarc                    1
# joze_walt                     1
# katevscanlan                  1
# zomelon                       1
#
# [82 rows x 1 columns]

# %%
sortcount = count_likes.sort_values('timestamp' ,ascending=False)
labels = sortcount['timestamp'].keys()
vals = sortcount['timestamp']
width = .75

fig, ax = plt.subplots(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
ax.bar(labels, vals, width)
ax.set_ylabel('Likes')
plt.xticks(rotation=90, fontsize = 'small')
plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.pie(vals, labels = labels)
ax2.axis('equal')
plt.show()

# %% [markdown]
# ### Conclusion
# We can see that I "liked" a lot of content from "bitchy.brown_". Beyond that, we can see that I also liked a lot of content from "p33p_b33p_m3m3_cr33p" and "reilleta", indicating a close relationship with those three users or enjoying the content from those accounts.
#
# Some limitations of this data set are that I cannot draw conclusions on the content of the accounts I liked, as this data does not include the tags of the posts I liked.
#
# In the future, I would like to add the "tags" data from the posts that I liked and compare the tags to see if there are any relationships or patterns that form, and draw conclusions from there.
